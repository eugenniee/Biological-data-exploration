# %%
import pandas as pd

# %%
pd.Series([1,1,2,3,5,8,13])
# Out:
# 0     1
# 1     1
# 2     2
# 3     3
# 4     5
# 5     8
# 6    13
# dtype: int64

# %%
apes = ["Homo sapiens", "Pan troglodytes", "Gorilla gorilla"]
conserved_sites = [24, 56, 132]
print(apes[0])
# Out:
# Homo sapiens

# %%
pd.Series ([3.1415, 2.7182, 1.4142])
# Out:
# 0    3.1415
# 1    2.7182
# 2    1.4142
# dtype: float64

# %%
s1 = pd.Series(["a", "b", "c", "d"], dtype = "string")
s2 = pd.Series([2, 4, 8, 16])
pd.DataFrame({"letter": s1, "number": s2})
# Out:
#   letter  number
# 0      a       2
# 1      b       4
# 2      c       8
# 3      d      16

# %%
df = pd.DataFrame({"letter": s1, "number": s2})
df.dtypes
# Out:
# letter     string
# number    float64
# dtype: object

# %%
#read_file.py
euk = pd.read_csv("eukaryotes.tsv ", sep = "\t")
euk
# print(euk) - gives slightly different output, might be harder to read
# Out:
#                          Species   Kingdom           Class   Size (Mb)  \
# 0     Emiliania huxleyi CCMP1516  Protists  Other Protists  167.676000
# 1           Arabidopsis thaliana    Plants     Land Plants  119.669000
# 2                    Glycine max    Plants     Land Plants  979.046000
# 3            Medicago truncatula    Plants     Land Plants  412.924000
# 4           Solanum lycopersicum    Plants     Land Plants  828.349000
# ...                          ...       ...             ...         ...
# 8297    Saccharomyces cerevisiae     Fungi     Ascomycetes    3.993920
# 8298    Saccharomyces cerevisiae     Fungi     Ascomycetes    0.586761
# 8299    Saccharomyces cerevisiae     Fungi     Ascomycetes   12.020400
# 8300    Saccharomyces cerevisiae     Fungi     Ascomycetes   11.960900
# 8301    Saccharomyces cerevisiae     Fungi     Ascomycetes   11.820700
#
#           GC% Number of genes Number of proteins  Publication year  \
# ...

# %%
# Using file path to open a file

path_to_file = "C:/Users/Evgeniia/Desktop/Work/Data-Analysis/example_files/introduction/eukaryotes.tsv"
euk = pd.read_csv(path_to_file, delim_whitespace=True) #, sep = "\t")
euk
# Out:
#                          Species   Kingdom           Class   Size (Mb)  \
# 0     Emiliania huxleyi CCMP1516  Protists  Other Protists  167.676000
# 1           Arabidopsis thaliana    Plants     Land Plants  119.669000
# 2                    Glycine max    Plants     Land Plants  979.046000
# 3            Medicago truncatula    Plants     Land Plants  412.924000
# 4           Solanum lycopersicum    Plants     Land Plants  828.349000
# ...                          ...       ...             ...         ...
# 8297    Saccharomyces cerevisiae     Fungi     Ascomycetes    3.993920
# 8298    Saccharomyces cerevisiae     Fungi     Ascomycetes    0.586761
# 8299    Saccharomyces cerevisiae     Fungi     Ascomycetes   12.020400
# 8300    Saccharomyces cerevisiae     Fungi     Ascomycetes   11.960900
# 8301    Saccharomyces cerevisiae     Fungi     Ascomycetes   11.820700
#
#           GC% Number of genes Number of proteins  Publication year  \
# ...

# %%
# Without tab separation
euk = pd.read_csv("eukaryotes.tsv")
euk
# Out:
#      Species\tKingdom\tClass\tSize (Mb)\tGC%\tNumber of genes\tNumber of proteins\tPublication year\tAssembly status
# 0     Emiliania huxleyi CCMP1516\tProtists\tOther Pr...
# 1     Arabidopsis thaliana\tPlants\tLand Plants\t119...
# 2     Glycine max\tPlants\tLand Plants\t979.046\t35....
# 3     Medicago truncatula\tPlants\tLand Plants\t412....
# 4     Solanum lycopersicum\tPlants\tLand Plants\t828...
# ...                                                 ...
# 8297  Saccharomyces cerevisiae\tFungi\tAscomycetes\t...
# 8298  Saccharomyces cerevisiae\tFungi\tAscomycetes\t...
# 8299  Saccharomyces cerevisiae\tFungi\tAscomycetes\t...
# 8300  Saccharomyces cerevisiae\tFungi\tAscomycetes\t...
# 8301  Saccharomyces cerevisiae\tFungi\tAscomycetes\t...
#
# [8302 rows x 1 columns]

# %%
euk.dtypes
# Out:
# Species                object
# Kingdom                object
# Class                  object
# Size (Mb)             float64
# GC%                    object
# Number of genes        object
# Number of proteins     object
# Publication year        int64
# Assembly status        object
# dtype: object

# %%
# Specify that several columns (Species, Kingdom, Class, Assembly) should be stored as strings. 

my_types = {
    "Species": "string",
    "Kingdom": "string",
    "Class": "string",
    "Assembly status": "string",
}

euk = pd.read_csv("eukaryotes.tsv", sep = "\t", dtype = my_types)
euk.dtypes
# Out:
# Species                string
# Kingdom                string
# Class                  string
# Size (Mb)             float64
# GC%                    object
# Number of genes        object
# Number of proteins     object
# Publication year        int64
# Assembly status        string
# dtype: object

# %%
# Looking at the last few rows in the dataframe.

euk.tail()
# Out:
#                        Species Kingdom        Class  Size (Mb)      GC%  \
# 8297  Saccharomyces cerevisiae   Fungi  Ascomycetes   3.993920     38.2
# 8298  Saccharomyces cerevisiae   Fungi  Ascomycetes   0.586761  38.5921
# 8299  Saccharomyces cerevisiae   Fungi  Ascomycetes  12.020400  38.2971
# 8300  Saccharomyces cerevisiae   Fungi  Ascomycetes  11.960900  38.2413
# 8301  Saccharomyces cerevisiae   Fungi  Ascomycetes  11.820700  38.2536
#
#      Number of genes Number of proteins  Publication year Assembly status
# 8297               -                  -              2017        Scaffold
# 8298             155                298              1992      Chromosome
# 8299               -                  -              2018      Chromosome
# 8300               -                  -              2018      Chromosome
# 8301               -                  -              2018      Chromosome

# %%
# How to tell pandas that the dash symbol means missing data.

euk = pd.read_csv("eukaryotes.tsv", sep = "\t", dtype = my_types, na_values = ["-"])
euk.tail()
# Out:
#                        Species Kingdom        Class  Size (Mb)      GC%  \
# 8297  Saccharomyces cerevisiae   Fungi  Ascomycetes   3.993920  38.2000
# 8298  Saccharomyces cerevisiae   Fungi  Ascomycetes   0.586761  38.5921
# 8299  Saccharomyces cerevisiae   Fungi  Ascomycetes  12.020400  38.2971
# 8300  Saccharomyces cerevisiae   Fungi  Ascomycetes  11.960900  38.2413
# 8301  Saccharomyces cerevisiae   Fungi  Ascomycetes  11.820700  38.2536
#
#       Number of genes  Number of proteins  Publication year Assembly status
# 8297              NaN                 NaN              2017        Scaffold
# 8298            155.0               298.0              1992      Chromosome
# 8299              NaN                 NaN              2018      Chromosome
# 8300              NaN                 NaN              2018      Chromosome
# 8301              NaN                 NaN              2018      Chromosome

# %%
euk.dtypes
# Out:
# Species                string
# Kingdom                string
# Class                  string
# Size (Mb)             float64
# GC%                   float64
# Number of genes       float64
# Number of proteins    float64
# Publication year        int64
# Assembly status        string
# dtype: object

# %%
# Pandas assumes that any numerical column with missing data must be floating point (like "Number of genes", "Number of proteins").
# We're adding these columns to the dtype dictionary.

my_types = {
    "Species": "string",
    "Kingdom": "string",
    "Class": "string",
    "Assembly status": "string",
    "Number of genes": "Int64",
    "Number of proteins": "Int64",
}

euk = pd.read_csv("eukaryotes.tsv", sep = "\t", dtype = my_types, na_values = ["-"])
euk.dtypes
# Out:
# Species                string
# Kingdom                string
# Class                  string
# Size (Mb)             float64
# GC%                   float64
# Number of genes         Int64
# Number of proteins      Int64
# Publication year        int64
# Assembly status        string
# dtype: object

# %%
# How to get more information about the data frame.
# No missing values in the "Publication year" column, that's why "int64" has a lowercase i.

euk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8302 entries, 0 to 8301
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Species             8302 non-null   string
#  1   Kingdom             8302 non-null   string
#  2   Class               8302 non-null   string
#  3   Size (Mb)           8302 non-null   float64
#  4   GC%                 7895 non-null   float64
#  5   Number of genes     2372 non-null   Int64
#  6   Number of proteins  2371 non-null   Int64
#  7   Publication year    8302 non-null   int64
#  8   Assembly status     8302 non-null   string
# dtypes: Int64(2), float64(2), int64(1), string(4)
# memory usage: 600.1 KB

# %%
# Descriptive statistics for all the numerical columns.

euk.describe()
# Out:
#           Size (Mb)          GC%  Number of genes  Number of proteins  \
# count   8302.000000  7895.000000      2372.000000         2371.000000
# mean     401.918437    43.230469     15098.307336        17137.252636
# std     1111.538289     7.998250     11505.437961        14735.085888
# min        0.011236     3.100000         3.000000            3.000000
# 25%       19.249775    38.219700      7361.500000         7010.500000
# 50%       39.559700    42.700000     11998.500000        12051.000000
# 75%      258.848000    49.000000     18303.500000        21671.000000
# max    32396.400000    73.500000    119453.000000       123467.000000
#
#        Publication year
# count       8302.000000
# mean        2015.849313
# std            2.924305
# min         1992.000000
# 25%         2015.000000
# 50%         2017.000000
# 75%         2018.000000
# max         2019.000000

# %%
type(euk)
# Out:
# pandas.core.frame.DataFrame

# %%
len(euk)
# Out:
# 8302

# %%
# How to change column names.

my_types = {
    "Species": "string", "Kingdom": "string", "Class": "string", "Assembly status": "string", "Number of genes": "Int64", "Number of proteins": "Int64",
}

my_names = [
    "species", "kingdom", "class", "size", "gc", "genes", "proteins", "year", "status"
]

pd.read_csv(
    "eukaryotes.tsv",
    sep = "\t",
    dtype = my_types,
    na_values = ["-"],
    #header = 0,
    names = my_names,
).head()
# Out:
#                       species   kingdom           class       size       gc  \
# 0                     Species   Kingdom           Class  Size (Mb)      GC%
# 1  Emiliania huxleyi CCMP1516  Protists  Other Protists    167.676     64.5
# 2        Arabidopsis thaliana    Plants     Land Plants    119.669  36.0529
# 3                 Glycine max    Plants     Land Plants    979.046  35.1153
# 4         Medicago truncatula    Plants     Land Plants    412.924   34.047
#
#              genes            proteins              year           status
# 0  Number of genes  Number of proteins  Publication year  Assembly status
# 1            38549               38554              2013         Scaffold
# 2            38311               48265              2001       Chromosome
# 3            59847               71219              2010       Chromosome
# 4            37603               41939              2011       Chromosome

# %%
# How to change column names, v2.

my_types = {
    "Species": "string", "Kingdom": "string", "Class": "string", "Assembly status": "string", "Number of genes": "Int64", "Number of proteins": "Int64",
}

my_names = [
    "species", "kingdom", "class", "size", "gc", "genes", "proteins", "year", "status"
]

df = pd.read_csv(
    "eukaryotes.tsv",
    sep = "\t",
    dtype = my_types,
    na_values = ["-"],
)

df.columns = my_names
df.head()
# Out:
#                       species   kingdom           class     size       gc  \
# 0  Emiliania huxleyi CCMP1516  Protists  Other Protists  167.676  64.5000
# 1        Arabidopsis thaliana    Plants     Land Plants  119.669  36.0529
# 2                 Glycine max    Plants     Land Plants  979.046  35.1153
# 3         Medicago truncatula    Plants     Land Plants  412.924  34.0470
# 4        Solanum lycopersicum    Plants     Land Plants  828.349  35.6991
#
#    genes  proteins  year      status
# 0  38549     38554  2013    Scaffold
# 1  38311     48265  2001  Chromosome
# 2  59847     71219  2010  Chromosome
# 3  37603     41939  2011  Chromosome
# 4  31200     37660  2010  Chromosome

# %%
df = pd.read_csv(
    "eukaryotes.tsv",
    sep = "\t",
    dtype = {"Species": "string", "Kingdom": "string", "Class": "string", "Assembly status": "string", "Number of genes": "Int64", "Number of proteins": "Int64"},
    na_values = ["-"],
)

df = df.rename(columns={"Species": "species", "Kingdom": "kingdom", "Class": "class", "Size (Mb)": "size"})

# Or rename the existing DataFrame (rather than creating a copy)
# df.rename(columns={"Species": "species", "Kingdom": "kingdom", "Class": "class", "Size (Mb)": "size"}, inplace=True)

df.head()
# Out:
#                       species   kingdom           class     size      GC%  \
# 0  Emiliania huxleyi CCMP1516  Protists  Other Protists  167.676  64.5000
# 1        Arabidopsis thaliana    Plants     Land Plants  119.669  36.0529
# 2                 Glycine max    Plants     Land Plants  979.046  35.1153
# 3         Medicago truncatula    Plants     Land Plants  412.924  34.0470
# 4        Solanum lycopersicum    Plants     Land Plants  828.349  35.6991
#
#    Number of genes  Number of proteins  Publication year Assembly status
# 0            38549               38554              2013        Scaffold
# 1            38311               48265              2001      Chromosome
# 2            59847               71219              2010      Chromosome
# 3            37603               41939              2011      Chromosome
# 4            31200               37660              2010      Chromosome

# %%
# To extract a single column

euk["Size (Mb)"]
# Out:
# 0       167.676000
# 1       119.669000
# 2       979.046000
# 3       412.924000
# 4       828.349000
#            ...
# 8297      3.993920
# 8298      0.586761
# 8299     12.020400
# 8300     11.960900
# 8301     11.820700
# Name: Size (Mb), Length: 8302, dtype: float64
